# %%
import matplotlib.pyplot as plot
import pandas as pd

file = pd.read_csv('Total_Population.csv')

file
# Out:
#                                      Label (Grouping)  \
# 0                                              Total:
# 1                                             Native:
# 2                          Born in state of residence
# 3           Born in other state in the United States:
# 4                                           Northeast
# 5                                             Midwest
# 6                                               South
# 7                                                West
# 8                     Born outside the United States:
# 9                                         Puerto Rico
# 10                                  U.S. Island Areas
# 11                  Born abroad of American parent(s)
# 12                                      Foreign born:
# 13                           Naturalized U.S. citizen
# 14                                             Europe
# 15                                               Asia
# ...

# %% [markdown]
# # New Section

# %%
new_file = pd.read_csv('Other_Pop.csv')
new_file
# Out:
#                              Label (Grouping)  \
# 0                            Total population
# 1                                         AGE
# 2                               Under 5 years
# 3                                5 to 9 years
# 4                              10 to 14 years
# 5                              15 to 19 years
# 6                              20 to 24 years
# 7                              25 to 29 years
# 8                              30 to 34 years
# 9                              35 to 39 years
# 10                             40 to 44 years
# 11                             45 to 49 years
# 12                             50 to 54 years
# 13                             55 to 59 years
# 14                             60 to 64 years
# 15                             65 to 69 years
# 16                             70 to 74 years
# 17                             75 to 79 years
# 18                             80 to 84 years
# ...

# %%
list(new_file.columns)
# Out:
# ['Label (Grouping)',
#  'Langley Park CDP, Maryland!!Total!!Estimate',
#  'Langley Park CDP, Maryland!!Total!!Margin of Error',
#  'Langley Park CDP, Maryland!!Percent!!Estimate',
#  'Langley Park CDP, Maryland!!Percent!!Margin of Error',
#  'Langley Park CDP, Maryland!!Male!!Estimate',
#  'Langley Park CDP, Maryland!!Male!!Margin of Error',
#  'Langley Park CDP, Maryland!!Percent Male!!Estimate',
#  'Langley Park CDP, Maryland!!Percent Male!!Margin of Error',
#  'Langley Park CDP, Maryland!!Female!!Estimate',
#  'Langley Park CDP, Maryland!!Female!!Margin of Error',
#  'Langley Park CDP, Maryland!!Percent Female!!Estimate',
#  'Langley Park CDP, Maryland!!Percent Female!!Margin of Error']

# %%
new_file = new_file.filter(items= ['Label (Grouping)', 'Langley Park CDP, Maryland!!Total!!Estimate'] )

# %%
new_file
# Out:
#                              Label (Grouping)  \
# 0                            Total population
# 1                                         AGE
# 2                               Under 5 years
# 3                                5 to 9 years
# 4                              10 to 14 years
# 5                              15 to 19 years
# 6                              20 to 24 years
# 7                              25 to 29 years
# 8                              30 to 34 years
# 9                              35 to 39 years
# 10                             40 to 44 years
# 11                             45 to 49 years
# 12                             50 to 54 years
# 13                             55 to 59 years
# 14                             60 to 64 years
# 15                             65 to 69 years
# 16                             70 to 74 years
# 17                             75 to 79 years
# 18                             80 to 84 years
# ...
