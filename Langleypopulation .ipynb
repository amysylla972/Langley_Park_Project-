# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import os
import streamlit as st
import plotly.express as px 
pd.options.mode.chained_assignment = None  # default='warn'

# %%
#Loading table 
nationality = pd.read_csv("../danin/Downloads/ACSDT5Y2020.B05002-2022-10-21T203244.csv")
nationality
# Out:
#                                      Label (Grouping)  \
# 0                                              Total:
# 1                                             Native:
# 2                          Born in state of residence
# 3           Born in other state in the United States:
# 4                                           Northeast
# 5                                             Midwest
# 6                                               South
# 7                                                West
# 8                     Born outside the United States:
# 9                                         Puerto Rico
# 10                                  U.S. Island Areas
# 11                  Born abroad of American parent(s)
# 12                                      Foreign born:
# 13                           Naturalized U.S. citizen
# 14                                             Europe
# 15                                               Asia
# ...

# %%
nationality
# Out:
#                                      Label (Grouping)  \
# 0                                              Total:
# 1                                             Native:
# 2                          Born in state of residence
# 3           Born in other state in the United States:
# 4                                           Northeast
# 5                                             Midwest
# 6                                               South
# 7                                                West
# 8                     Born outside the United States:
# 9                                         Puerto Rico
# 10                                  U.S. Island Areas
# 11                  Born abroad of American parent(s)
# 12                                      Foreign born:
# 13                           Naturalized U.S. citizen
# 14                                             Europe
# 15                                               Asia
# ...

# %%
#Drop extraneous data from table
nationality.drop(nationality.index[4:8], inplace=True)
nationality
# Out:
#                                      Label (Grouping)  \
# 0                                              Total:
# 1                                             Native:
# 2                          Born in state of residence
# 3           Born in other state in the United States:
# 8                     Born outside the United States:
# 9                                         Puerto Rico
# 10                                  U.S. Island Areas
# 11                  Born abroad of American parent(s)
# 12                                      Foreign born:
# 13                           Naturalized U.S. citizen
# 14                                             Europe
# 15                                               Asia
# 16                                             Africa
# 17                                            Oceania
# 18                                      Latin America
# 19                                   Northern America
# ...

# %%
#MORE TRIMING ON NATIONALITY 
nationality = nationality.iloc[:17]
nationality
# Out:
#                                      Label (Grouping)  \
# 0                                              Total:
# 1                                             Native:
# 2                          Born in state of residence
# 3           Born in other state in the United States:
# 8                     Born outside the United States:
# 9                                         Puerto Rico
# 10                                  U.S. Island Areas
# 11                  Born abroad of American parent(s)
# 12                                      Foreign born:
# 13                           Naturalized U.S. citizen
# 14                                             Europe
# 15                                               Asia
# 16                                             Africa
# 17                                            Oceania
# 18                                      Latin America
# 19                                   Northern America
# ...

# %%
#Reset the index
nationality.reset_index()
# Out:
#     index                                   Label (Grouping)  \
# 0       0                                             Total:
# 1       1                                            Native:
# 2       2                         Born in state of residence
# 3       3          Born in other state in the United States:
# 4       8                    Born outside the United States:
# 5       9                                        Puerto Rico
# 6      10                                  U.S. Island Areas
# 7      11                  Born abroad of American parent(s)
# 8      12                                      Foreign born:
# 9      13                           Naturalized U.S. citizen
# 10     14                                             Europe
# 11     15                                               Asia
# 12     16                                             Africa
# 13     17                                            Oceania
# ...

# %%
#Names of current columns 
list(nationality.columns)
# Out:
# ['Label (Grouping)',
#  'Langley Park CDP, Maryland!!Estimate',
#  'Langley Park CDP, Maryland!!Margin of Error']

# %%
nationality.reset_index(drop=True, inplace=True)

# %%
nationality
# Out:
#                                      Label (Grouping)  \
# 0                                              Total:
# 1                                             Native:
# 2                          Born in state of residence
# 3           Born in other state in the United States:
# 4                     Born outside the United States:
# 5                                         Puerto Rico
# 6                                   U.S. Island Areas
# 7                   Born abroad of American parent(s)
# 8                                       Foreign born:
# 9                            Naturalized U.S. citizen
# 10                                             Europe
# 11                                               Asia
# 12                                             Africa
# 13                                            Oceania
# 14                                      Latin America
# 15                                   Northern America
# ...

# %%
#Drop extraneous data from table
nationality.drop(nationality.index[5:7], inplace=True)
nationality
# Out:
#                                      Label (Grouping)  \
# 0                                              Total:
# 1                                             Native:
# 2                          Born in state of residence
# 3           Born in other state in the United States:
# 4                     Born outside the United States:
# 7                   Born abroad of American parent(s)
# 8                                       Foreign born:
# 9                            Naturalized U.S. citizen
# 10                                             Europe
# 11                                               Asia
# 12                                             Africa
# 13                                            Oceania
# 14                                      Latin America
# 15                                   Northern America
# 16                                 Not a U.S. citizen
#
#     Langley Park CDP, Maryland!!Estimate  \
# 0                                19391.0
# ...

# %%
nationality
# Out:
#                                      Label (Grouping)  \
# 0                                              Total:
# 1                                             Native:
# 2                          Born in state of residence
# 3           Born in other state in the United States:
# 4                     Born outside the United States:
# 7                   Born abroad of American parent(s)
# 8                                       Foreign born:
# 9                            Naturalized U.S. citizen
# 10                                             Europe
# 11                                               Asia
# 12                                             Africa
# 13                                            Oceania
# 14                                      Latin America
# 15                                   Northern America
# 16                                 Not a U.S. citizen
#
#     Langley Park CDP, Maryland!!Estimate  \
# 0                                19391.0
# ...

# %%
#Remove extra columns 
nationality.drop(columns = 'Langley Park CDP, Maryland!!Margin of Error')
# Out:
#                                      Label (Grouping)  \
# 0                                              Total:
# 1                                             Native:
# 2                          Born in state of residence
# 3           Born in other state in the United States:
# 4                     Born outside the United States:
# 7                   Born abroad of American parent(s)
# 8                                       Foreign born:
# 9                            Naturalized U.S. citizen
# 10                                             Europe
# 11                                               Asia
# 12                                             Africa
# 13                                            Oceania
# 14                                      Latin America
# 15                                   Northern America
# 16                                 Not a U.S. citizen
#
#     Langley Park CDP, Maryland!!Estimate
# 0                                19391.0
# ...

# %%
#Drop extraneous information 
nationality.drop(0)
# Out:
#                                      Label (Grouping)  \
# 1                                             Native:
# 2                          Born in state of residence
# 3           Born in other state in the United States:
# 4                     Born outside the United States:
# 7                   Born abroad of American parent(s)
# 8                                       Foreign born:
# 9                            Naturalized U.S. citizen
# 10                                             Europe
# 11                                               Asia
# 12                                             Africa
# 13                                            Oceania
# 14                                      Latin America
# 15                                   Northern America
# 16                                 Not a U.S. citizen
#
#     Langley Park CDP, Maryland!!Estimate  \
# 1                                 7439.0
# 2                                 4270.0
# ...

# %%
nationality = nationality.drop(columns = 'Langley Park CDP, Maryland!!Margin of Error')
nationality.reset_index(drop=True, inplace=True)

# %%
nationality
# Out:
#                                      Label (Grouping)  \
# 0                                              Total:
# 1                                             Native:
# 2                          Born in state of residence
# 3           Born in other state in the United States:
# 4                     Born outside the United States:
# 5                   Born abroad of American parent(s)
# 6                                       Foreign born:
# 7                            Naturalized U.S. citizen
# 8                                              Europe
# 9                                                Asia
# 10                                             Africa
# 11                                            Oceania
# 12                                      Latin America
# 13                                   Northern America
# 14                                 Not a U.S. citizen
#
#     Langley Park CDP, Maryland!!Estimate
# 0                                19391.0
# ...

# %%
nationality.drop(nationality.index[8:14], inplace=True)

# %%
nationality
# Out:
#                                      Label (Grouping)  \
# 0                                              Total:
# 1                                             Native:
# 2                          Born in state of residence
# 3           Born in other state in the United States:
# 4                     Born outside the United States:
# 5                   Born abroad of American parent(s)
# 6                                       Foreign born:
# 7                            Naturalized U.S. citizen
# 14                                 Not a U.S. citizen
#
#     Langley Park CDP, Maryland!!Estimate
# 0                                19391.0
# 1                                 7439.0
# 2                                 4270.0
# 3                                 2929.0
# 4                                  240.0
# 5                                  205.0
# 6                                11952.0
# 7                                 1835.0
# 14                               10117.0

# %%
nationality.reset_index(drop=True, inplace=True)

# %%
nationality
# Out:
#                                     Label (Grouping)  \
# 0                                             Total:
# 1                                            Native:
# 2                         Born in state of residence
# 3          Born in other state in the United States:
# 4                    Born outside the United States:
# 5                  Born abroad of American parent(s)
# 6                                      Foreign born:
# 7                           Naturalized U.S. citizen
# 8                                 Not a U.S. citizen
#
#    Langley Park CDP, Maryland!!Estimate
# 0                               19391.0
# 1                                7439.0
# 2                                4270.0
# 3                                2929.0
# 4                                 240.0
# 5                                 205.0
# 6                               11952.0
# 7                                1835.0
# 8                               10117.0

# %%
nationality.drop(0,inplace=True)

# %%
nationality
# Out:
#                                     Label (Grouping)  \
# 1                                            Native:
# 2                         Born in state of residence
# 3          Born in other state in the United States:
# 4                    Born outside the United States:
# 5                  Born abroad of American parent(s)
# 6                                      Foreign born:
# 7                           Naturalized U.S. citizen
# 8                                 Not a U.S. citizen
#
#    Langley Park CDP, Maryland!!Estimate
# 1                                7439.0
# 2                                4270.0
# 3                                2929.0
# 4                                 240.0
# 5                                 205.0
# 6                               11952.0
# 7                                1835.0
# 8                               10117.0

# %%
nationality = nationality.rename(columns={"Label (Grouping)": "Category", "Langley Park CDP, Maryland!!Estimate": "Estimate"})

# %%
nationality = nationality.replace(':',' ')

# %%
nationality
# Out:
#                                             Category  Estimate
# 1                                            Native:    7439.0
# 2                         Born in state of residence    4270.0
# 3          Born in other state in the United States:    2929.0
# 4                    Born outside the United States:     240.0
# 5                  Born abroad of American parent(s)     205.0
# 6                                      Foreign born:   11952.0
# 7                           Naturalized U.S. citizen    1835.0
# 8                                 Not a U.S. citizen   10117.0

# %%
plt.style.use('ggplot')
table = nationality.plot.barh(x='Category', y='Estimate')

# %%
foreign = pd.read_csv("../danin/Downloads/ACSDT5Y2020.B05002-2022-10-21T203244.csv")
foreign
# Out:
#                                      Label (Grouping)  \
# 0                                              Total:
# 1                                             Native:
# 2                          Born in state of residence
# 3           Born in other state in the United States:
# 4                                           Northeast
# 5                                             Midwest
# 6                                               South
# 7                                                West
# 8                     Born outside the United States:
# 9                                         Puerto Rico
# 10                                  U.S. Island Areas
# 11                  Born abroad of American parent(s)
# 12                                      Foreign born:
# 13                           Naturalized U.S. citizen
# 14                                             Europe
# 15                                               Asia
# ...

# %%
#Remove extraneous information 
foreign = foreign.drop(columns = 'Langley Park CDP, Maryland!!Margin of Error')
foreign.drop(foreign.index[0:20], inplace=True)
foreign.reset_index(drop=True, inplace=True)

# %%
foreign
# Out:
#                Label (Grouping)  Langley Park CDP, Maryland!!Estimate
# 0            Not a U.S. citizen                               10117.0
# 1                        Europe                                  54.0
# 2                          Asia                                 115.0
# 3                        Africa                                 621.0
# 4                       Oceania                                   0.0
# 5                 Latin America                                9327.0
# 6              Northern America                                   0.0

# %%
#Clean/create the Non US citizen table 
foreign.drop(0,inplace=True)
foreign.reset_index(drop=True, inplace=True)
foreign = foreign.rename(columns={"Label (Grouping)": "Category", "Langley Park CDP, Maryland!!Estimate": "Estimate"})

# %%
foreign
# Out:
#                        Category  Estimate
# 0                        Europe      54.0
# 1                          Asia     115.0
# 2                        Africa     621.0
# 3                       Oceania       0.0
# 4                 Latin America    9327.0
# 5              Northern America       0.0

# %%
#Non Us Citizen 
plt.style.use('ggplot')
df_sorted = foreign.sort_values('Estimate')
plt.barh('Category', 'Estimate', data=df_sorted, color='orange')

plt.show()

# %%
bournout = pd.read_csv("../danin/Downloads/ACSDT5Y2020.B05002-2022-10-21T203244.csv")
bournout
# Out:
#                                      Label (Grouping)  \
# 0                                              Total:
# 1                                             Native:
# 2                          Born in state of residence
# 3           Born in other state in the United States:
# 4                                           Northeast
# 5                                             Midwest
# 6                                               South
# 7                                                West
# 8                     Born outside the United States:
# 9                                         Puerto Rico
# 10                                  U.S. Island Areas
# 11                  Born abroad of American parent(s)
# 12                                      Foreign born:
# 13                           Naturalized U.S. citizen
# 14                                             Europe
# 15                                               Asia
# ...

# %%
#Remove extraneous information 
bournout = bournout.drop(columns = 'Langley Park CDP, Maryland!!Margin of Error')
bournout.drop(bournout.index[0:12], inplace=True)
bournout.reset_index(drop=True, inplace=True)

# %%
bournout
# Out:
#                     Label (Grouping)  Langley Park CDP, Maryland!!Estimate
# 0                      Foreign born:                               11952.0
# 1           Naturalized U.S. citizen                                1835.0
# 2                             Europe                                   6.0
# 3                               Asia                                  84.0
# 4                             Africa                                 359.0
# 5                            Oceania                                   0.0
# 6                      Latin America                                1386.0
# 7                   Northern America                                   0.0
# 8                 Not a U.S. citizen                               10117.0
# 9                             Europe                                  54.0
# 10                              Asia                                 115.0
# ...

# %%
bournout.drop(bournout.index[8:14], inplace=True)

# %%
bournout.reset_index(drop=True, inplace=True)
bournout
# Out:
#                    Label (Grouping)  Langley Park CDP, Maryland!!Estimate
# 0                     Foreign born:                               11952.0
# 1          Naturalized U.S. citizen                                1835.0
# 2                            Europe                                   6.0
# 3                              Asia                                  84.0
# 4                            Africa                                 359.0
# 5                           Oceania                                   0.0
# 6                     Latin America                                1386.0
# 7                  Northern America                                   0.0
# 8                  Northern America                                   0.0

# %%
bournout.drop(8,inplace=True)

# %%
bournout
# Out:
#                    Label (Grouping)  Langley Park CDP, Maryland!!Estimate
# 0                     Foreign born:                               11952.0
# 1          Naturalized U.S. citizen                                1835.0
# 2                            Europe                                   6.0
# 3                              Asia                                  84.0
# 4                            Africa                                 359.0
# 5                           Oceania                                   0.0
# 6                     Latin America                                1386.0
# 7                  Northern America                                   0.0

# %%
#Clean/create the Non US citizen table 
bournout.drop(0,inplace=True)
bournout.reset_index(drop=True, inplace=True)
bournout = bournout.rename(columns={"Label (Grouping)": "Category", "Langley Park CDP, Maryland!!Estimate": "Estimate"})

# %%
#Born outside the us 
plt.style.use('ggplot')
df_sorted = bournout.sort_values('Estimate')
plt.barh('Category', 'Estimate', data=df_sorted, color='green')

plt.show()
